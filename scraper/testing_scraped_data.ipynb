# %%
import pandas as pd
from textblob import TextBlob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <module>
#       1 import pandas as pd
# ----> 2 from textblob import TextBlob
#
# ModuleNotFoundError: No module named 'textblob'

# %%
# df = pd.read_csv("data/comments_july6.csv")
df = pd.read_csv("data/junk.csv")

# %%
df.head(10)
# Out:
#        videoId                                        textDisplay  \
# 0  EBOKYsWUhvI  Dub maro jaato 😢😢.<br>Tumse tumare ladkiya nhi...
# 1  EBOKYsWUhvI                                   Haar gye bechare
# 2  EBOKYsWUhvI  Dhamki mili pahalwano ko aur sab manage kr liy...
# 3  EBOKYsWUhvI  Jaato pr ye boj rhega ki vo apni hi vyavstha s...
# 4  EBOKYsWUhvI           Pahlwan jante h kuch nhi kr payenge uska
# 5  EBOKYsWUhvI  Logo ko ullu bana ke ye sab mahanubhav chal di...
# 6  EBOKYsWUhvI  Ye Bhabhita Fogat naam ki mahila ko Brijh Bhus...
# 7  EBOKYsWUhvI          इनके विरुद्ध तो सख्त एक्शन लेना चाहिए था।
# 8  EBOKYsWUhvI  bina trial khele sirf ek boyt ke baad Okympic ...
# 9  EBOKYsWUhvI  Ye sb drama kr rahe the, inko bs chhut chahiye...
#
#                                         textOriginal    authorDisplayName  \
# 0  Dub maro jaato 😢😢.\nTumse tumare ladkiya nhi b...       HECTOR OF TROY
# 1                                   Haar gye bechare          Geeta Saini
# ...

# %%
df.shape
# Out:
# (81912, 14)
