# %%
import pandas as pd

# %%
df = pd.read_csv(r'comments.csv')

# %%
df.shape
# Out:
# (18252, 15)

# %%
df
# Out:
#                       channelId      videoId  \
# 0      UCBIHkGh0iJahfzq4SFmfjcA  9g3692xrYog
# 1      UCBIHkGh0iJahfzq4SFmfjcA  9g3692xrYog
# 2      UCBIHkGh0iJahfzq4SFmfjcA  9g3692xrYog
# 3      UCBIHkGh0iJahfzq4SFmfjcA  9g3692xrYog
# 4      UCBIHkGh0iJahfzq4SFmfjcA  9g3692xrYog
# ...                         ...          ...
# 18247  UCBIHkGh0iJahfzq4SFmfjcA  _ShclHTKJoY
# 18248  UCBIHkGh0iJahfzq4SFmfjcA  _ShclHTKJoY
# 18249  UCBIHkGh0iJahfzq4SFmfjcA  _ShclHTKJoY
# 18250  UCBIHkGh0iJahfzq4SFmfjcA  _ShclHTKJoY
# 18251  UCBIHkGh0iJahfzq4SFmfjcA  _ShclHTKJoY
#
#                                              textDisplay  \
# 0      Cylinder BUFFALO, how much u lie, don’t say ur...
# 1                                                Jhuti .
# 2                                  Murdabad smriti Irani
# 3      Smriti tera carrier khtm modi ji chai tak pe b...
# 4      A building with a weak foundation can not be s...
# ...                                                  ...
# ...

# %%
df.columns
# Out:
# Index(['channelId', 'videoId', 'textDisplay', 'textOriginal',
#        'authorDisplayName', 'authorProfileImageUrl', 'authorChannelUrl',
#        'authorChannelId', 'canRate', 'viewerRating', 'likeCount',
#        'publishedAt', 'updatedAt', 'parentId', 'commentId'],
#       dtype='object')
