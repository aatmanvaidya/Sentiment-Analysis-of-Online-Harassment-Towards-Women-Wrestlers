# %%
import pandas as pd

# %%
df = pd.read_csv(r'test.csv')

# %%
df.shape
# Out:
# (292, 15)

# %%
df
# Out:
#                     channelId      videoId  \
# 0    UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 1    UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 2    UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 3    UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 4    UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# ..                        ...          ...
# 287  UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 288  UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 289  UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 290  UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
# 291  UC_b1GUJv_2QiMP4BxC9-Dxg  36N1Bz7qW0A
#
#                                            textDisplay  \
# 0                            Thank you for doing this!
# 1    I thought just followers of Dhoni are only cur...
# 2                      Awesome content keep posting 👍❤
# 3    really a great conversation between u guys ,le...
# 4    It&#39;s really wow, the way Prachi explained ...
# ..                                                 ...
# ...
