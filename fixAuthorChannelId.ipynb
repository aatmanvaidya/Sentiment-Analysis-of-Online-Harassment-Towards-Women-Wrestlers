# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('comments.csv')

# %%
 df.head()
# Out:
#        videoId                                        textDisplay  \
# 0  G4EVRUFttG0  Our community is creating +100 memes per day!\...
# 1  G4EVRUFttG0                        SPIDERMAN IS KHALISTANI 😢😢😢
# 2  G4EVRUFttG0                  What’s a example of a canon event
# 3  G4EVRUFttG0  Delete and Apologize. Or my masterclass awaits...
# 4  G4EVRUFttG0                               Ain&#39;t no way 💀💀☠
#
#                                         textOriginal authorDisplayName  \
# 0  Our community is creating +100 memes per day!\...        MemeMandir
# 1                        SPIDERMAN IS KHALISTANI 😢😢😢                Do
# 2                  What’s a example of a canon event       Its_Mikaela
# 3  Delete and Apologize. Or my masterclass awaits...      Ankit Pandey
# 4                                   Ain't no way 💀💀☠      Darshil Jain
#
#                                authorProfileImageUrl  \
# 0  https://yt3.ggpht.com/ytc/AGIKgqMp5pvb5WoGDH5I...
# ...

# %%
df['authorChannelId'] = df['authorChannelId'].apply(lambda x: ast.literal_eval(x)['value'])

# %%
df = df.drop(['authorProfileImageUrl', 'authorChannelUrl'], axis=1)

# %%
df.head()
# Out:
#        videoId                                        textDisplay  \
# 0  G4EVRUFttG0  Our community is creating +100 memes per day!\...
# 1  G4EVRUFttG0                        SPIDERMAN IS KHALISTANI 😢😢😢
# 2  G4EVRUFttG0                  What’s a example of a canon event
# 3  G4EVRUFttG0  Delete and Apologize. Or my masterclass awaits...
# 4  G4EVRUFttG0                               Ain&#39;t no way 💀💀☠
#
#                                         textOriginal authorDisplayName  \
# 0  Our community is creating +100 memes per day!\...        MemeMandir
# 1                        SPIDERMAN IS KHALISTANI 😢😢😢                Do
# 2                  What’s a example of a canon event       Its_Mikaela
# 3  Delete and Apologize. Or my masterclass awaits...      Ankit Pandey
# 4                                   Ain't no way 💀💀☠      Darshil Jain
#
#             authorChannelId  canRate viewerRating  likeCount  \
# 0  UCg5ogbPlpn8DN-NrLPK12VQ     True         none          2
# ...
